# %% [markdown]
# # LinkedList

# %% [raw]
# Def  :  Linkedlist contains the Node , Node contains the data and the address of the next node

# %%
#creating the node of the LinkedList
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

# %%
#create the object of the linked list
#also the nodes are connected to each other
head = Node(10)
head.next = Node(20)
head.next.next = Node(30)
head.next.next.next = Node(40)

# %%
print(head.data)
# Out:
# 10

# %%
print(head.next.data)
# Out:
# 20

# %%
print(head.next.next.data)
# Out:
# 30

# %%
#Instead of doing these... we can first create the objects then connect them manually
#creating the node of the LinkedList
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

# %%
#here we created the ojects
first = Node(10)
second = Node(20)
third = Node(30)
fourth = Node(40)

# %%
print(first.next)
#because we arent connect the nodes yet
# Out:
# None

# %%
#here we connect the nodes
first.next = second
second.next = third
third.next = fourth

# %%
print(first.next)
#it gives the address of the second node

# %% [markdown]
# # Traversal

# %%
current = first
while current :
    print(current.data)
    current = current.next
# Out:
# 10
# 20
# 30
# 40

# %% [markdown]
# # Insert The Node in the Middle

# %%
# create the inserted Node object
mid = Node(25)

# %%
#we want to add these in the middle 
mid.next = third
second.next = mid

# %%
current = first
while current :
    print(current.data)
    current = current.next
#see here , the node added in the middle , but these is specific .... position we took
# Out:
# 10
# 20
# 25
# 30
# 40

# %%
def insert(first, value,new_value):
    current = first
    while current:
        if current.data == value:
            #create the node
            new_node = Node(new_value)
            new_node.next = current.next
            current.next = new_node
            return first
        current = current.next
    return first

# %%
first = insert(first,30,35)

# %%
current = first
while current :
    print(current.data)
    current = current.next
#here we added the 35 as on the required position...
# Out:
# 10
# 20
# 25
# 30
# 35
# 40

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\PANCHAKRUSHNA TECH\DSA PYTHON\LEET CODE DSA PROBLEMS

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
    def Insert_Beg(value):
        current = first
        new_node = Node(value)
        new_node.next = current
        curent = new_node
        return "Added Successfully"

    def print_data():
        current = first 
        while current :
            print(current.data)
            current = current.next
        
    def Insert_mid(value,element):
        current = first
        while current :
            if current.data ==value:
                new_node = Node(element)
                new_node.next = current.next
                current.next = new_node
            current = current.next
    def Insert_end(value):
        current = first
        while current is None:
            new_node = Node(value)
            current.next = new_node

# %%
first = Node(1)
second = Node(2)
third = Node(3)
fourth = Node(4)
fifth = Node(5)
first.next = second
second.next = third
third.next = fourth
fourth.next = fifth

# %%
current  = first
while current :
    print(current.data)
    current = current.next
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
Node.Insert_Beg(0)
# Out:
# 'Added Successfully'

# %%
Node.Insert_mid(3,45)

# %%
Node.print_data()
# Out:
# 1
# 2
# 3
# 45
# 4
# 5

# %%
Node.Insert_end(100)

# %%
Node.print_data()
# Out:
# 1
# 2
# 3
# 45
# 4
# 5

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


class LinkedList:

    def __init__(self):
        self.head = None

    def insert_beg(self, value):
        new_node = Node(value)

        new_node.next = self.head
        self.head = new_node

    def print_data(self):
        current = self.head

        while current:
            print(current.data, end=" -> ")
            current = current.next

        print("None")

    def insert_mid(self, value, element):
        current = self.head

        while current:
            if current.data == value:
                new_node = Node(element)

                new_node.next = current.next
                current.next = new_node

                return

            current = current.next

    def insert_end(self, value):
        new_node = Node(value)

        # Empty list
        if self.head is None:
            self.head = new_node
            return

        current = self.head

        while current.next:
            current = current.next

        current.next = new_node

# %%
# Linkded List Full Code 
#creation of the Node
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

#we create the 2nd class called as LinkedList
class LinkedList:
    def __init__(self):
        self.head = None
    def insert_beg(self,value):
        new_node = Node(value)
        new_node.next = self.head
        self.head = new_node

    def print_data(self):
        current = self.head
        while current:
            print(current.data)
            current = current.next
    def insert_mid(self,value,target):
        current = self.head
        while current:
            if current.data ==target:
                new_node = Node(value)
                new_node.next = current.next
                current.next = new_node
                return
            current = current.next
    def insert_end(self,value):

        new_node =  Node(value)
        if self.head is None:
            self.head  = new_node
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = new_node

# %%
ll = LinkedList()
ll.insert_beg(100)

# %%
ll.print_data()
# Out:
# 100

# %%
ll.insert_end(1000)

# %%
ll.insert_mid(500,100)

# %%
ll.print_data()
# Out:
# 100
# 500
# 1000

# %%
ll.insert_mid(250,100)

# %%
ll.print_data()
# Out:
# 100
# 250
# 500
# 1000
